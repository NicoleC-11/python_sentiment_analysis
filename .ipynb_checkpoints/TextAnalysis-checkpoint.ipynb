# %% [markdown]
# ## Importing Libraries and Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('ggplot')

# natural language toolkit for sentiment analysis
import nltk

# %%
df = pd.read_csv('C:/Users/skate/Desktop/text_analysis/Reviews.csv')
print(df.shape)
# Out:
# (568454, 10)

# %%
# dataset is too large - take a sample of the dataset instead of the whole thing
#df = df.head(500)
#print(df.shape)

# %%
df.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# ...

# %%
reviewChart = df['Score'].value_counts().sort_index().plot(kind='bar', title='Number of Reviews by Stars', figsize = (10,5))
reviewChart.set_xlabel('Review Stars')
plt.show()

# %% [markdown]
# # Testing NLTK Features Using the Dataset

# %%
# take a random review as an example
example = df['Text'][50]
print(example)
# Out:
# This oatmeal is not good. Its mushy, soft, I don't like it. Quaker Oats is the way to go.

# %%
# splits the review into individual strings, or "tokens", including punctuation
tokens = nltk.word_tokenize(example)
tokens[:10]
# Out:
# ['This', 'oatmeal', 'is', 'not', 'good', '.', 'Its', 'mushy', ',', 'soft']

# %%
# tags each word with a marker that marks what part of a sentence it is (noun, adjective, etc.)
tagged_tokens = nltk.pos_tag(tokens)
tagged_tokens[:10]
# Out:
# [('This', 'DT'),
#  ('oatmeal', 'NN'),
#  ('is', 'VBZ'),
#  ('not', 'RB'),
#  ('good', 'JJ'),
#  ('.', '.'),
#  ('Its', 'PRP$'),
#  ('mushy', 'NN'),
#  (',', ','),
#  ('soft', 'JJ')]

# %%
# takes a list of tagged tokens and groups them into chunks of text
entities = nltk.chunk.ne_chunk(tagged_tokens)
entities.pprint()
# Out:
# (S
#   This/DT
#   oatmeal/NN
#   is/VBZ
#   not/RB
#   good/JJ
#   ./.
#   Its/PRP$
#   mushy/NN
#   ,/,
#   soft/JJ
#   ,/,
#   I/PRP
#   do/VBP
#   n't/RB
#   like/VB
#   it/PRP
#   ./.
#   (ORGANIZATION Quaker/NNP Oats/NNPS)
#   is/VBZ
#   the/DT
#   way/NN
#   to/TO
#   go/VB
#   ./.)

# %% [markdown]
# With the words appropriately tokenized, tagged, and chunked, we can use the sentiment intensity analyzer to determine how positive or negative each review is. To do this, we will need to repeat this process for the whole dataset, then analyze these tagged chunks.

# %% [markdown]
# # NLTK Sentiment Scoring
# We will use python's NLTK, or natural language toolkit, library in order to generate numerical scores for a review's overall sentiment towards an item. This toolkit uses a bag of words approach to approximate the positive or negative sentiment of each individual word, then averages the score of all the words to find the overall scoring. Notably, this approach does not account for context between words, since it only analyzes words individually. However, it provides a decent starting point to analyze sentiment.

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
from tqdm import tqdm

sia = SentimentIntensityAnalyzer()

# %%
sia.polarity_scores('I am so happy!')
# Out:
# {'neg': 0.0, 'neu': 0.318, 'pos': 0.682, 'compound': 0.6468}

# %%
sia.polarity_scores('This is the worst thing ever.')
# Out:
# {'neg': 0.451, 'neu': 0.549, 'pos': 0.0, 'compound': -0.6249}

# %%
# example = 'This oatmeal is not good. Its mushy, soft, I don't like it. Quaker Oats is the way to go.'
sia.polarity_scores(example)
# Out:
# {'neg': 0.22, 'neu': 0.78, 'pos': 0.0, 'compound': -0.5448}

# %% [markdown]
# After running these examples, we can conclude that the sentiment analysis is working properly. The first example was strongly positive, and resulted in a compound score of 0.65. The second example was negative, and produced a compound score of -0.62. Therefore, we can see that the values are scored from -1 to 1, with negative scores being negative sentiments, 0 being neutral, and 1 being positive.
#
# When we input our earlier example text from the dataset, which states "This oatmeal is not good. Its mushy, soft, I don't like it. Quaker Oats is the way to go", we find that we recieve a compound score of -0.54, which is reasonably negative. Since it appears to be working well on these examples, we will now run the sentiment analysis on the entire dataset and save the values to a dataframe.

# %%
# Run the polarity score on the entire dataset 
# note: this can take a while
result = {}
for i, row in tqdm(df.iterrows(), total=len(df)):
    text = row['Text']
    myid = row['Id']
    result[myid] = sia.polarity_scores(text)
# Out:
# 100%|██████████| 568454/568454 [07:19<00:00, 1292.10it/s]

# %%
# import results into a dataframe and flip the dataframe
sentiment = pd.DataFrame(result).T
# rename index
sentiment = sentiment.reset_index().rename(columns={'index':'Id'})
# left join sentiment scores with original data
sentiment = sentiment.merge(df, how='left')

# %%
sentiment.head()
# Out:
#    Id    neg    neu    pos  compound   ProductId          UserId  \
# 0   1  0.000  0.695  0.305    0.9441  B001E4KFG0  A3SGXH7AUHU8GW
# 1   2  0.138  0.862  0.000   -0.5664  B00813GRG4  A1D87F6ZCVE5NK
# 2   3  0.091  0.754  0.155    0.8265  B000LQOCH0   ABXLMWJIXXAIN
# 3   4  0.000  1.000  0.000    0.0000  B000UA0QIQ  A395BORC6FGVXV
# 4   5  0.000  0.552  0.448    0.9468  B006K2ZZ7K  A1UQRSCLF8GW1T
#
#                        ProfileName  HelpfulnessNumerator  \
# 0                       delmartian                     1
# 1                           dll pa                     0
# 2  Natalia Corres "Natalia Corres"                     1
# 3                             Karl                     3
# 4    Michael D. Bigham "M. Wassir"                     0
#
#    HelpfulnessDenominator  Score        Time                Summary  \
# 0                       1      5  1303862400  Good Quality Dog Food
# 1                       0      1  1346976000      Not as Advertised
# ...

# %% [markdown]
# # Plot Results

# %%
compound_graph = sns.barplot(data=sentiment, x='Score', y='compound')
compound_graph.set_title('Compound Score by Amazon Star Review')
# Out:
# Text(0.5, 1.0, 'Compound Score by Amazon Star Review')

# %% [markdown]
# The compound score is an aggregation of the positive and negative scores for a statement, providing an overall sentiment. As we can see from this plot, the compound scores seem to generally follow the number of stars a review has given a product, which is a good sign. However, we can also check the positive, negative, and neutral scores to ensure they follow the star ratings as expected.

# %%
fig, axs = plt.subplots(1, 3, figsize=(12,5))
sns.barplot(data=sentiment, x='Score', y='pos', ax=axs[0])
sns.barplot(data=sentiment, x='Score', y='neu', ax=axs[1])
sns.barplot(data=sentiment, x='Score', y='neg', ax=axs[2])
axs[0].set_title('Positive')
axs[1].set_title('Neutral')
axs[2].set_title('Negative')
plt.tight_layout()
plt.show()

# %% [markdown]
# The scores generally match the number of stars, as we would expect, and so we can conclude that this sentiment analysis is reasonably accurate, despite its shortcomings.
#
# Now that we have fully tested the sentiment of the dataset as a whole, we can filter it and check the sentiments for specific criteria, such as helpfulness or certain phrases.

# %%
helpful = sentiment.query('HelpfulnessNumerator > 30')
print(helpful.shape)
# Out:
# (2778, 14)

# %%
helpfulness_graph = sns.barplot(data=helpful, x='Score', y='compound')
helpfulness_graph.set_title('Compound Score by Stars (Only Helpful Reviews)')
plt.show()

# %% [markdown]
# In this dataset, the "HelpfulnessNumerator" is a count of the number of people who found the review helpful. When we filter the data to view only reviews with more than 30 helpfulness, we find that although the sentiments still generally match the star ratings, one star reviews have a significantly higher sentiment rating. This could potentially mean that people tend to find a review more helpful when it is providing some positive feedback as well.
#
# To examine this further, we'll take a look at review sentiment versus helpfulness.

# %%
helpfulSentimentGraph = sns.scatterplot(data=sentiment, x='compound', y='HelpfulnessNumerator')
helpfulSentimentGraph.set_title('Review Helpfulness by Sentiment (Overall)')
plt.show()

# %% [markdown]
# Looking at the review helpfulness by sentiment rating, we see a range of helpful reviews. Throughout all sentiment scores, there are a fair amount of helpful reviews. However, there does seem to be a trend towards positive sentiments being the most helpful, with a much higher concentration of reviews on the far right of the scatterplot.

# %%
oneStar = sentiment.query('Score == 1 and HelpfulnessNumerator > 0')
print(oneStar.shape)
# Out:
# (31942, 14)

# %%
fiveStar = sentiment.query('Score == 5 and HelpfulnessNumerator > 0')
print(fiveStar.shape)
# Out:
# (164741, 14)

# %%
fig, axs = plt.subplots(1, 2, figsize=(12,5))
# one star reviews
sns.scatterplot(data=oneStar, x='compound', y='HelpfulnessNumerator', ax=axs[0])
# five star reviews
sns.scatterplot(data=fiveStar, x='compound', y='HelpfulnessNumerator', ax=axs[1])

axs[0].set_title('1-Star Review Helpfulness by Sentiment Rating')
axs[1].set_title('5-Star Review Helpfulness by Sentiment Rating')
plt.show()

# %% [markdown]
# Most reviews which fall under a certain amount of helpfulness are fairly evenly spaced among sentiment scores for both one and five star reviews. However, we can see that the outliers in the five star reviews have a much stronger preference towards extremely positive sentiments.

# %%
products['AvgSentiment'] = sentiment.groupby('ProductId')['compound'].agg(['mean'])

# %%
products['AvgScore'] = sentiment.groupby('ProductId')['Score'].agg(['mean'])

# %%
products['NumReviews'] = sentiment.groupby('ProductId').size()

# %%
products.head()
# Out:
#             AvgSentiment  AvgScore  NumReviews
# ProductId
# 7310172001      0.717323  4.751445         173
# 7310172101      0.717323  4.751445         173
# B00004CI84      0.673962  4.486772         189
# B00004CXX9      0.655486  4.405128         195
# B00004RAMY     -0.013934  4.104651         172

# %%
print(products.shape)
# Out:
# (521, 3)

# %%
products = products.query('NumReviews > 50')
print(products.shape)
# Out:
# (521, 3)

# %%
productsGraph = sns.scatterplot(data=products, x='AvgScore', y='AvgSentiment', palette='plasma', hue='NumReviews')
productsGraph.set_title('Average Review Sentiment by Average Score Per Product')
plt.show()
